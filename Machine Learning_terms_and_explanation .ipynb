# %% [markdown]
# ### MACHINE LEARNING TERMS AND ITS DEFINITION ###
#
# This Notebook describes basic **ML and NN** terms for quick understanding and reference for anytime.
#
# 1. Regression
# 2. Classification
# 3. Clustering
# 4. Associate
# 5. Neural Networks

# %% [markdown]
# #### REGRESSION TECHNIQUE ####
#
# 1. **Mean** => Overall average value of N inputs
#
# 2. **Standard Deviation** => Square Root of 1/N Summation(i=0 to N) (x(i) - mean)^2 it is also called **Population SD**
#                           **Sample SD** => Square Root of 1/N summation(i=0 to N-1) (x(i)-mean)^2
#
# 3. **covarience** => Is a measure of  much **two random variables** vary together.
#           Cov(x,y) = Summation(i=0 to N) (x(i)-mean(x)) * (y(i)-mean(y)) / N-1
#
# 4. **corelation** => Corelation between Two data
#
# 5. **Simple Linear Regression** => Linear Relationship to modeling the scalar response one or more responsible variables
#                         y = a + b * x
#                     x => input_data, {a,b} => someconstantvalue, y=>output
#
# 6. **Ordinary Least Square** =>  procedure seeks to minimize the sum of square resuidals. This means given a regression line we calculate **distance from datapoint to the regression line**, square it, and sum of all square error together. For **Multiple Linear Regression** find the **Regression Plane** and calculate sum of squares error calculation.

# %% [markdown]
# 7. **Mean squared Error(MSE)** => Way to measure how well its predictions actually match the observed data.
#                             = 1 / N (Summation(y(i)-f(x(i))^2) where range is 1 to N
#
#
# 8. **Coordinate Descent** => Derivative that minimization of a multivariable function F(x) along one direction at a time. To optimize the network, Choose one coordinate(randomly) and iterate through all the N data.
#
#
#
# 9. **sum of squared Error(SSE)** => 1/2 sum(actual_data - predicted_data)^2. ie.., here predicted_data is nothing but a linear regression line.
#
#
#
# 10. **Gradient Descent** => [https://www.kdnuggets.com/2017/04/simple-understand-gradient-descent-algorithm.html] Refer this link for better understanding

# %% [markdown]
# ### LOGISTIC REGRESSION ###
#
# Logistic Classifier is more like a **Linear Classifier** which uses **Logistic scores** to classify the input. To classify the input data **softmax** Algorithm is used.
#
# 1. **Softmax** => np.exp(logits_value)/np.sum(np.exp(logits_value),axis=0) here **axis=0** represents Dimensions

# %% [markdown]
# ### OVER FITTING AND UNDER FITTING ###
#
# 1. **OverFitting** => Model trained too well, and gives best accuracy. Best fails to predict the class when it comes to new data
# 2. **UnderFitting** => Vice versa to overfitting. The model performs poor both on Training data and new data.
#
# ![image.png](attachment:image.png)
#
# 3. **Cross Validation** => splitting our data into K subsets, and train on one of **k-1 subsets** and validate the model on rest k model. There are two types of cross validation
#            3.1 **KFold validation** => split our data into K subset and train on K-1 subset and leave the last subset. We then average each of the hold and validate our model
#            3.2 **Leave One Out Cross Validation**

# %% [markdown]
# ### CLUSTERING ###
#
# Following are types of Clusters
#
# 1. Hierarchical Clustering  => also known as **nesting clustering** as it also clusters to exists within bigger clusters to form a tree
#
# 2. Partition Clustering => Division of set of data objects into non-overlapping clusters such that each object is exactly one subset
#
# 3. Exclusive Clustering => They assign each value to single cluster
#
# 4. Overlapping Clustering => Used to reflect the fact than an object can simultaneously belong to more than one group
#
# 5. Fuzzy Clustering => Every object belong to every cluster with a membership weight that goes between 0: if its absolutely belong to the cluster, 1: if it completly belongs to the cluster
#
# 6. Complete Clustering => It perform **Hierarchical Clustering** using a set of dissimilarities on 'n' objects that are being clustered.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DECISION TREE ###
#
# It's a supervised learning algorithm that used for **classification**. It works for both **categorical and continuous** input and output variables. We split the population or sample into **two or more homogeneous** sets based on most significant splitter/ differentiator in input variables
#
# ####  TERMINOLOGIES IN DECISION TREE ####
#
# 1. ROOT Node => It represents the entire population or sample this further gets divided into two or more homogeneous set
# 2. SPLITTING => Process of dividing a node into further sub nodes.
# 3. Leaf/Terminal nodes => Nodes do not split into Terminals or Leaf node
# 4. Pruning => When we remove the sub nodes of decision nodes, this process is called as pruning.
# 5. Branch/Sub-Tree => A sub section of entire tree is called branch or sub-tree.
#
# Decision Tree follows **Sum of Product (SOP)** representation. The main problem in Decision Tree is to **select the attributes**. Using **Information Gain, Gini Index** we can select the attributes that have to **root node** at certain levels.
#
# For Information Gain
# (i) Calculate **Entropy** of the Target
#
# (ii) calculating Entropy for every attribute in the dataset, using Information gain we subtract Entropy of target - Entropy of attributes(N numbers)
#
# #### ENTROPY ####
#
# Entropy is a measure of **how Tidy your data is?**. In general Entropy is a measure of how messy your data is.
#
# [http://dataaspirant.com/2017/01/30/how-decision-tree-algorithm-works/] Refer this link for further reading

# %% [markdown]
# ### GINI INDEX ###
#
# Gini Index is a **metric to measure how often a randomly chosen element would be incorrectly identified.** It means the attribute with **lower gini index** would be prefered.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### RANDOM FOREST ###
#
# Random Forest built a **multiple decision Trees** and merge them together to get more accurate and stable predictions. It can be used in both **classification and regression** problem.
#
# **PRECISION AND RECALL** => It's a metric used to evaluate the classifier problem. It's a successfull measure of prediction when the classes are totally **unbalanced.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **oob Score** => OOB scoring also called as **OOB Sampling** which is a random forest classification method. In this sampling about **1/3 of training data is not used** to test the model and can be used to evaluate its performance. This sample are also called as **Out of bag samples**.

# %% [markdown]
# ### SUPPORT VECTOR MACHINE ###
#
# A discriminative classifier used for **classification and regression** problem used **Non-linear classifier** separating by hyperplane.
#
# #### TERMS ####
#
# Kernel, Regularization, Gamma and Margin
#
# To learn further more, read this blog: [https://medium.com/machine-learning-101/chapter-2-svm-support-vector-machine-theory-f0812effc72]
